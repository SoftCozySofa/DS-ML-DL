# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

os.chdir("C:/ames")

plt.style.use('ggplot')

# %matplotlib inline

# %%
diss = pd.read_csv("Diss.csv")
diss.columns = ['Dissertation name']
diss.index.name = 'Index'
diss.head()
# Out:
#                                        Dissertation name
# Index
# 0      Сравнительный анализ геномов крупного рогатого...
# 1      Влияние субтропического климата на работу изги...
# 2      Информационная защита телекоммуникационных сис...
# 3      Разработка механизированного пресса и выбор па...
# 4      Спектроскопическое исследование оптических ком...

# %%
diss['Number of symbols'] = diss['Dissertation name'].str.len()
diss['Number of words'] = diss['Dissertation name'].str.split().apply(len)
diss[diss['Dissertation name'].str.contains("рентген")]
#diss[diss['Number of words'] == 1][diss['Number of symbols'] < 5]
# Out:
# C:\Users\PRINT\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#        Dissertation name  Number of symbols  Number of words
# Index
# 25990               Риск                  4                1
# 39351               Кант                  4                1
# 49466                США                  3                1
# 57671               Куба                  4                1
# 89503               США                   4                1
# 95799                ФРГ                  3                1
# 108232              Сап                   4                1
# 151593               ИАГ                  3                1
# 185645              NADH                  4                1
# 196650               ФРГ                  3                1
# 213405               США                  3                1
# 224700               Мир                  3                1
# ...

# %%
diss['Number of words'].hist(figsize=(12, 12), bins=38)

# %%
diss.boxplot('Number of words', figsize=(12, 12))

# %%
sns.boxplot(diss['Number of words'])

# %%
sns.distplot(diss['Number of words'], bins=38)

# %%
plt.figure(figsize=(12, 12))
plt.scatter(diss['Index'][:1000], diss['Number of words'][:1000])

# %%
plt.figure(figsize=(12, 12))
plt.scatter(diss['Number of symbols'][:1000], diss['Number of words'][:1000])
